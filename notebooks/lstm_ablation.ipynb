# %%
import matplotlib.pyplot as plt
import numpy as np

# First model train loss (E5)
train_loss_no_sliding_window_no_feature = [
    4.457842041696357,
    1.999903442973727,
    1.9670522330821938,
    1.8807840714805613,
    1.8146528279656429,
    1.760566696135207,
    1.6983332247945369,
    1.6791392285901179,
    1.6610143705233678,
    1.6171575572782357,
    1.6052061619594262,
    1.5799048952781827,
    1.5988415250301422,
    1.5327659273310121,
    1.4603384789787237,
    1.5056067437870366,
    1.4767370156576018,
    1.4264070723878812,
    1.4399182465082165,
    1.4187573183366948
]

# Second model train loss (add your second model data here)
train_loss_no_feature = [
    2.3092880164594183,
    1.2333028373912704,
    1.181192935739649,
    1.126049033335221,
    1.0700305497732117,
    0.9748478715670499,
    1.026038215847317,
    1.0282400449468185,
    0.9729692203470921,
    0.9332715156418162,
    0.9171144351816557,
    0.9046908052427242,
    0.9299573319651475,
    0.8940722776202749,
    0.9095465387152446,
    0.941402463566217,
    0.8635863654993652,
    0.8682724065498306,
    0.8663028096677889,
    0.8881522183947425
]

train_loss = [
    1.4566789975883894,
    0.6653336327254449,
    0.3588915493787501,
    0.3350757733072059,
    0.3321807880512829,
    0.3407635244305365,
    0.342782181859197,
    0.33993105228020076,
    0.34618798316864485,
    0.35580656497921853,
    0.3536680320412082,
    0.35185355062892437
]

# Create a line graph of training loss
plt.figure(figsize=(10, 6))

# Plot all 20 epochs for the first two models
epochs_20 = np.arange(1, 21)
plt.plot(epochs_20, train_loss_no_sliding_window_no_feature, marker='o', linestyle='-', color='blue', label='Without Sliding Window and Features')
plt.plot(epochs_20, train_loss_no_feature, marker='s', linestyle='-', color='red', label='Without Features')

# Plot all 12 epochs for the third model
epochs_12 = np.arange(1, 13)
plt.plot(epochs_12, train_loss, marker='^', linestyle='-', color='green', label='With Sliding Window and Features')

plt.title('Training Loss Comparison Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# First model train loss (E5)
val_loss_no_sliding_window_no_feature = [
    4.457842041696357,
    1.999903442973727,
    1.9670522330821938,
    1.8807840714805613,
    1.8146528279656429,
    1.760566696135207,
    1.6983332247945369,
    1.6791392285901179,
    1.6610143705233678,
    1.6171575572782357,
    1.6052061619594262,
    1.5799048952781827,
    1.5988415250301422,
    1.5327659273310121,
    1.4603384789787237,
    1.5056067437870366,
    1.4767370156576018,
    1.4264070723878812,
    1.4399182465082165,
    1.4187573183366948
]

# Second model train loss (add your second model data here)
val_loss_no_feature = [
    0.9036826012465488,
    0.9345240843573843,
    0.8955093263492758,
    0.7279747440097543,
    0.6738052810216747,
    0.6391509798522416,
    0.6720679215747173,
    0.6204278580806659,
    0.6728987273474233,
    0.6132891135858306,
    0.6207949272767389,
    0.6414719431716741,
    0.6760142114024756,
    0.6040759337226187,
    0.648167517168302,
    0.5756323198658596,
    0.6414617614663963,
    0.7422512229211183,
    0.575083415679777,
    0.6880602755082776
]

val_loss = [
    0.20786096434945878,
    0.16800512571223722,
    0.4528788681752534,
    0.15873325438726515,
    0.08333635898618351,
    0.7351833585547821,
    0.38081668252399026,
    0.4147529009627716,
    0.12273788118495284,
    0.17969982152410313,
    0.4366766642835727,
    0.0866419111417178
]

# Create a line graph of training loss
plt.figure(figsize=(10, 6))

# Plot all 20 epochs for the first two models
epochs_20 = np.arange(1, 21)
plt.plot(epochs_20, val_loss_no_sliding_window_no_feature, marker='o', linestyle='-', color='blue', label='Without Sliding Window and Features')
plt.plot(epochs_20, val_loss_no_feature, marker='s', linestyle='-', color='red', label='Without Features')

# Plot all 12 epochs for the third model
epochs_12 = np.arange(1, 13)
plt.plot(epochs_12, val_loss, marker='^', linestyle='-', color='green', label='With Sliding Window and Features')

plt.title('Training Loss Comparison Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.tight_layout()
plt.show()
